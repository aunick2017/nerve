# %%
from plotly.offline import plot

figure_or_data = {'data': [{'x': [1, 2], 'y': [0, 1], 'z': [2, 2], 'type': 'scatter3d'}],
                  'layout': {'xaxis': {'range': [0, 3], 'autorange': False},
                             'yaxis': {'range': [0, 20], 'autorange': False},
                             'zaxis': {'range': [0, 20], 'autorange': False},
                             'title': 'First Title'},
                  'frames': [{'data': [{'x': [1, 2], 'y': [5, 7], 'z': [1, 2]}]},
                             {'data': [{'x': [-1, 3], 'y': [3, 9], 'z': [2, 2]}]},
                             {'data': [{'x': [2, 2.6], 'y': [7, 5], 'z': [3, 7]}]},
                             {'data': [{'x': [1.5, 3], 'y': [7.5, 4], 'z': [4, 7]}]},
                             {'data': [{'x': [1, 2], 'y': [0, 1], 'z': [5, 1]}],
                             'layout': {'title': 'End Title'}}]}

plot(figure_or_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-1da4152a5138> in <module>()
#      13                              'layout': {'title': 'End Title'}}]}
#      14
# ---> 15 plot(figure_or_data)
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/offline/offline.py in plot(figure_or_data, show_link, link_text, validate, output_type, include_plotlyjs, filename, auto_open, image, image_filename, image_width, image_height, config)
#     474     plot_html, plotdivid, width, height = _plot_html(
#     475         figure_or_data, config, validate,
# --> 476         '100%', '100%', global_requirejs=False)
#     477
#     478     resize_script = ''
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/offline/offline.py in _plot_html(figure_or_data, config, validate, default_width, default_height, global_requirejs)
#     152                default_height, global_requirejs):
# ...
